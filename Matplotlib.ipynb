# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
x = np.arange(0,10)
y=np.arange(11,21)

# %%
plt.scatter(x,y,color='r')
plt.xlabel('X axis')
plt.ylabel('Y label')
plt.title("Graphic 2D")

##save figure
plt.savefig("a.jpg")

# %%
y=x*x

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)

# %% [markdown]
# ## Histogram

# %%
# a = np.array([12,1,16,18,2,112,1,22,22,25,45,45,48,63,63,65,59])
plt.hist(a)
# Out:
# (array([4., 4., 1., 2., 1., 4., 0., 0., 0., 1.]),
#  array([  1. ,  12.1,  23.2,  34.3,  45.4,  56.5,  67.6,  78.7,  89.8,
#         100.9, 112. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Subplots

# %%
## subpots

plt.subplot(2,2,1)
plt.plot(x,y,'g*')

plt.subplot(2,2,2)
plt.plot(x,y,'r+')

plt.subplot(2,2,3)
plt.plot(x,y,'bo')

plt.subplot(2,2,4)
plt.plot(x,y,'y--')

# %% [markdown]
# ## Box Plot

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

## patch_artist = color
## vert == verticals

plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x234a8412cc0>,
#   <matplotlib.lines.Line2D at 0x234a8412e10>,
#   <matplotlib.lines.Line2D at 0x234a841f940>,
#   <matplotlib.lines.Line2D at 0x234a841fa90>,
#   <matplotlib.lines.Line2D at 0x234a8430550>,
#   <matplotlib.lines.Line2D at 0x234a84306a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x234a84172e8>,
#   <matplotlib.lines.Line2D at 0x234a8417710>,
#   <matplotlib.lines.Line2D at 0x234a841feb8>,
#   <matplotlib.lines.Line2D at 0x234a8428320>,
#   <matplotlib.lines.Line2D at 0x234a8430ac8>,
#   <matplotlib.lines.Line2D at 0x234a8430ef0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x234a8412a58>,
#   <matplotlib.patches.PathPatch at 0x234a841f6d8>,
#   <matplotlib.patches.PathPatch at 0x234a84302b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x234a8417b38>,
#   <matplotlib.lines.Line2D at 0x234a8428748>,
#   <matplotlib.lines.Line2D at 0x234a8439358>],
#  'fliers': [<matplotlib.lines.Line2D at 0x234a8417f60>,
#   <matplotlib.lines.Line2D at 0x234a8428b70>,
#   <matplotlib.lines.Line2D at 0x234a8439780>],
#  'means': []}

# %% [markdown]
# #  Pi chart

# %%
labels = 'python','C++', 'Ruby', 'Java'
sizes = [215,130,245,210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.5,0.6,.19,0) #explode 1st slice

#ploting
plt.pie(sizes, explode = explode,labels=labels,colors=colors,autopct=
       '%1.1f%%',shadow=True)
plt.axis('equal')
plt.show()
